# %% [markdown]
# # 07차시: 금융 시계열 데이터 시각화 (주가 차트 그리기)
#
# ## 학습 목표
# - Pandas로 읽은 주가 데이터를 Matplotlib으로 시계열 차트로 시각화
# - 주가 차트(캔들 차트 등) 그리기 실습
#
# ## 구분
# 실습
#
# ---
# *이 노트북의 상세 내용은 강사가 제공하는 자료를 기반으로 작성됩니다.*
