# %% [markdown]
# # 04차시: Pandas로 금융 데이터 다루기 (읽기, 쓰기, 선택, 필터링)
#
# ## 학습 목표
# - CSV, Excel 파일(주가 데이터 등) 읽고 쓰기
# - 원하는 데이터(특정 날짜, 특정 종목) 선택하고 필터링하기
#
# ## 구분
# 실습
#
# ---
# *이 노트북의 상세 내용은 강사가 제공하는 자료를 기반으로 작성됩니다.*
